# %% [markdown]
# <a href="https://colab.research.google.com/github/tridip14/SalesDataAnalyticsAI/blob/main/Sales_Data_Analytics-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('sales_dataset.csv')
df['Sales'] = df['Quantity'] * df['Unit_Price']
print(df)
# Out:
#    Month     Product     Category  Quantity  Unit_Price   Sales
# 0    Jan      Laptop  Electronics         5       55000  275000
# 1    Jan       Phone  Electronics         8       22000  176000
# 2    Jan  Headphones  Accessories        15        2000   30000
# 3    Feb      Laptop  Electronics         6       55000  330000
# 4    Feb       Phone  Electronics        10       22000  220000
# 5    Feb  Headphones  Accessories        18        2000   36000
# 6    Mar      Laptop  Electronics         7       55000  385000
# 7    Mar       Phone  Electronics        12       22000  264000
# 8    Mar  Headphones  Accessories        20        2000   40000
# 9    Apr      Laptop  Electronics         8       55000  440000
# 10   Apr       Phone  Electronics        14       22000  308000
# 11   Apr  Headphones  Accessories        22        2000   44000
# 12   May      Laptop  Electronics         9       55000  495000
# 13   May       Phone  Electronics        15       22000  330000
# ...

# %%
print('Total Sales:', df['Sales'].sum())
print('Average Sales:', df['Sales'].mean())
# Out:
# Total Sales: 4403000
# Average Sales: 244611.11111111112

# %%
product_sales = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
print(product_sales)
product_sales.plot(kind='bar', title='Sales by Product')
plt.ylabel('Sales')
plt.show()
# Out:
# Product
# Laptop        2475000
# Phone         1672000
# Headphones     256000
# Name: Sales, dtype: int64

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()
print(monthly_sales)
monthly_sales.plot(kind='line', marker='o', title='Monthly Sales Trend')
plt.ylabel('Sales')
plt.show()
# Out:
# Month
# Apr    792000
# Feb    586000
# Jan    481000
# Jun    980000
# Mar    689000
# May    875000
# Name: Sales, dtype: int64

# %%
X = pd.DataFrame({'Month_Number': range(1, 7)})
y = monthly_sales.values
model = LinearRegression()
model.fit(X, y)
prediction = model.predict(pd.DataFrame({'Month_Number':[7]}))
print('Predicted Sales for next month:', round(prediction[0], 2))
# Out:
# Predicted Sales for next month: 856133.33
